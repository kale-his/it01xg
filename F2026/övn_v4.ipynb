# %% [markdown]
# ### Övning. Numerisk beräkning av integraler utifrån värdetabeller.
#
# Låt oss skapa en funktion som numeriskt uppskattar integralen av en funktion, utifrån en följd av givna funktionsvärden.
#
# Om $y_i = f(x_i)$, där $x_0<x_1<...<x_n$ så ger trapetsformeln
# $$ T = \sum_{k=0}^{n-1} \frac{\left(y_k + y_{k+1}\right)}{2}\left(x_{k+1}-x_{k}\right) $$
# en uppskattning av integralen
# $$\int_{x_0}^{x_n}f(x)\,dx,$$
# egentligen värdet av integralen om grafen till $f$ består av räta linjestycken på varje intervall  $[x_{k},x_{k+1}]$.
#
# Skapa en funktion som beräknar integralen enligt trapetsformeln

# %%
def trapets(xs,ys):
    ''' Returnerar värdet enligt trapetsformeln av integralen givet en följd av punkter på grafen,
      med x- och y-koordinaterna i xs och ys.
    Värdena i xs förutsätts vara strängt växande.'''
    # Implementera

# %% [markdown]
# Testa på integralen
# $$\int_0^{\pi}\sin(x)\,dx$$
# med olika antal delintervall. (Vad är integralens exakta värde?)
# Vi behöver då två listor, en med x-värden och en med funktionsvärden (y-värden).
#
# Pröva också andra integraler.
#
# Hur skapar vi en lista `xs` av $n+1$ ändpunkter till $n$ lika långa intervall mellan $a$ och $b$?
#
# En lista av funktionsvärden kan vi sedan skapa antingen med en for-loop, eller med list comprehension.

# %%
# math.sin och math.pi finns i modulen math
import math
# 
# Givet en följd av x-värden xs kan vi skapa en följd av funktionsvärden f(x) med list comprehension:
ys = [ f(x) for x in xs ]
# eller med en loop
ys = []
for x in xs:
    ys.append(f(x))

# %% [markdown]
# Antag nu att $n=2m$ är ett jämnt tal och att alla delintervall är lika stora, $x_{k}-x_{k-1} = h$.
# Simpsons formel,
# $$S = \frac{h}{3}\sum_{k=0}^{m-1}\left(y_{2k}+4y_{2k+1}+y_{2k+2}\right) = \frac{h}{3}\left(y_0+4y_1+2y_2+4y_3+...+2y_{2m-2}+4y_{2m-1}+y_{2m}\right).$$
#  ger värdet en uppskattning av integralen som är exakt $f(x)$ på varje delintervall $[x_{2k},x_{2(k+1)}]$ ges av ett andragradspolynom.
#
#  Skapa nu en funktion som beräknar integralen enligt Simpsons formel.

# %%
def simpson(xs, ys):
    ''' Returnerar värdet enligt trapetsformeln av integralen givet en följd av punkter på grafen,
      med x- och y-koordinaterna i xs och ys.
    Värdena i xs förutsätts vara strängt växande.'''
    # Implementera

# %% [markdown]
# Testa på samma följder som tidigare.
