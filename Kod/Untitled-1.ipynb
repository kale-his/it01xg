# %%
1+2
# Out:
# 3

# %%
1+2
# Out:
# 3

# %%
uinp = input("Ge mig en kommaseparerad lista av tal")

# %%
uinp
# Out:
# '1,2,3,4'

# %%
list(uinp)
# Out:
# ['1', ',', '2', ',', '3', ',', '4']

# %%
ll=list(uinp.split(','))

# %%
[float(a) for a in ll]
# Out:
# [1.0, 2.0, 3.0, 4.0]
